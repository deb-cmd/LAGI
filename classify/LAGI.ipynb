# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.1)
# Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.7 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.1.0

# %%
# pip install faker pandas

import pandas as pd
import random
from faker import Faker

# Initialize Faker and set seed for reproducibility
fake = Faker()
random.seed(42)
Faker.seed(42)

def generate_query_dataset(samples_per_category=200, output_file='query_dataset.csv'):
    """
    Generates a synthetic dataset of queries with categories:
    0 - Code, 1 - Reason, 2 - Language
    """
    categories = {
        0: "code",
        1: "reason",
        2: "language"
    }

    # Patterns and vocabulary components
    components = {
        "code": {
            "patterns": [
                "How to implement {algorithm} in {language}?",
                "Fix {error} in {language} code",
                "Best practices for {framework} development",
                "Tutorial on {tech} authentication",
                "Debugging {language} memory leaks"
            ],
            "variables": {
                "algorithm": ["binary search", "quicksort", "DFS", "A* algorithm"],
                "language": ["Python", "Java", "C++", "JavaScript"],
                "error": ["seg fault", "null pointer", "syntax error"],
                "framework": ["Django", "React", "Spring Boot"],
                "tech": ["OAuth2", "JWT", "SSL"]
            }
        },
        "reason": {
            "patterns": [
                "Why does {phenomenon} occur?",
                "Explain {concept}",
                "What causes {event}?",
                "How does {process} work?",
                "Scientific explanation of {topic}"
            ],
            "variables": {
                "phenomenon": ["gravity", "tides", "aurora borealis"],
                "concept": ["quantum entanglement", "relativity", "evolution"],
                "event": ["earthquakes", "volcanic eruptions", "tornadoes"],
                "process": ["photosynthesis", "nuclear fission", "digestion"],
                "topic": ["climate change", "black holes", "sleep patterns"]
            }
        },
        "language": {
            "patterns": [
                "Translate '{phrase}' to {lang}",
                "How to say {phrase} in {lang}?",
                "{lang} grammar rules for {grammar}",
                "Pronunciation of {word} in {lang}",
                "Difference between {lang1} and {lang2}"
            ],
            "variables": {
                "phrase": ["Hello", "Thank you", "Where is the bathroom?"],
                "lang": ["Spanish", "French", "German", "Mandarin"],
                "grammar": ["past tense", "subjunctive mood", "articles"],
                "word": ["hello", "goodbye", "please"],
                "lang1": ["Spanish", "French"],
                "lang2": ["Italian", "Portuguese"]
            }
        }
    }

    dataset = []
    for category_id, category_name in categories.items():
        cat_data = components[category_name]
        for _ in range(samples_per_category):
            pattern = random.choice(cat_data["patterns"])
            replacements = {}
            for key in cat_data["variables"]:
                if f"{{{key}}}" in pattern:
                    replacements[key] = random.choice(cat_data["variables"][key])
            query = pattern.format(**replacements)
            dataset.append({"query": query, "category": category_id})

    df = pd.DataFrame(dataset)
    df.to_csv(output_file, index=False)
    print(f"Dataset generated with {len(df)} samples. Saved to {output_file}")


generate_query_dataset(samples_per_category=500, output_file='query_dataset.csv')
# Out:
# Dataset generated with 1500 samples. Saved to query_dataset.csv

# %%
# Install required packages
# pip install tensorflow sentence-transformers pandas scikit-learn

import tensorflow as tf
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Check GPU availability
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# Load dataset
df = pd.read_csv('query_dataset.csv')
texts = df['query'].tolist()
labels = df['category'].values

# Generate embeddings using GPU
model = SentenceTransformer('all-MiniLM-L6-v2', device='cuda')
embeddings = model.encode(texts, show_progress_bar=True, convert_to_numpy=True)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    embeddings, labels, test_size=0.2, random_state=42, stratify=labels
)

# Create ANN model
def create_model(input_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(256, activation='relu', input_shape=(input_dim,)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Initialize and train model with GPU
with tf.device('/GPU:0') if tf.config.list_physical_devices('GPU') else tf.device('/CPU:0'):
    ann = create_model(embeddings.shape[1])

    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True
    )

    history = ann.fit(
        X_train, y_train,
        epochs=50,
        batch_size=256,
        validation_split=0.2,
        callbacks=[early_stop],
        verbose=1
    )

# Evaluate model
test_loss, test_acc = ann.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_acc:.4f}")

# Generate predictions
y_pred = np.argmax(ann.predict(X_test), axis=1)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Save the trained model
ann.save('query_classifier_model.keras')
print("Model saved as 'query_classifier_model.keras'")

# Example prediction function
def predict_query(text):
    embedding = model.encode([text], device='cuda')
    prediction = ann.predict(embedding)
    categories = {0: 'code', 1: 'reason', 2: 'language'}
    return categories[np.argmax(prediction)]
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Batches:   0%|          | 0/47 [00:00<?, ?it/s]
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 743ms/step - accuracy: 0.5050 - loss: 1.0762 - val_accuracy: 0.9625 - val_loss: 0.9785
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9562 - loss: 0.9541 - val_accuracy: 0.9958 - val_loss: 0.7933
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9965 - loss: 0.7611 - val_accuracy: 0.9958 - val_loss: 0.5451
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9963 - loss: 0.5147 - val_accuracy: 1.0000 - val_loss: 0.2991
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9956 - loss: 0.2734 - val_accuracy: 1.0000 - val_loss: 0.1270
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1111 - val_accuracy: 1.0000 - val_loss: 0.0395
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0356 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 9.7263e-04 - val_accuracy: 1.0000 - val_loss: 5.0535e-04
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 4.9364e-04 - val_accuracy: 1.0000 - val_loss: 2.9109e-04
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.9974e-04 - val_accuracy: 1.0000 - val_loss: 1.9396e-04
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.0761e-04 - val_accuracy: 1.0000 - val_loss: 1.4346e-04
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.4248e-04 - val_accuracy: 1.0000 - val_loss: 1.1471e-04
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.3547e-04 - val_accuracy: 1.0000 - val_loss: 9.6985e-05
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.0590e-04 - val_accuracy: 1.0000 - val_loss: 8.5451e-05
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 1.0824e-04 - val_accuracy: 1.0000 - val_loss: 7.7402e-05
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 7.9263e-05 - val_accuracy: 1.0000 - val_loss: 7.1694e-05
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 7.6129e-05 - val_accuracy: 1.0000 - val_loss: 6.7405e-05
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 8.4960e-05 - val_accuracy: 1.0000 - val_loss: 6.3965e-05
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.3082e-05 - val_accuracy: 1.0000 - val_loss: 6.1090e-05
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 7.3755e-05 - val_accuracy: 1.0000 - val_loss: 5.8653e-05
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 7.3108e-05 - val_accuracy: 1.0000 - val_loss: 5.6549e-05
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 7.6784e-05 - val_accuracy: 1.0000 - val_loss: 5.4574e-05
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.9272e-05 - val_accuracy: 1.0000 - val_loss: 5.2785e-05
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 7.9886e-05 - val_accuracy: 1.0000 - val_loss: 5.1168e-05
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 6.1245e-05 - val_accuracy: 1.0000 - val_loss: 4.9707e-05
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 7.0888e-05 - val_accuracy: 1.0000 - val_loss: 4.8342e-05
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 5.4254e-05 - val_accuracy: 1.0000 - val_loss: 4.7091e-05
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 6.0280e-05 - val_accuracy: 1.0000 - val_loss: 4.5962e-05
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 6.0678e-05 - val_accuracy: 1.0000 - val_loss: 4.4857e-05
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 6.2917e-05 - val_accuracy: 1.0000 - val_loss: 4.3811e-05
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.6913e-05 - val_accuracy: 1.0000 - val_loss: 4.2779e-05
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.1132e-05 - val_accuracy: 1.0000 - val_loss: 4.1827e-05
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.3773e-05 - val_accuracy: 1.0000 - val_loss: 4.0863e-05
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.9704e-05 - val_accuracy: 1.0000 - val_loss: 3.9969e-05
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.7707e-05 - val_accuracy: 1.0000 - val_loss: 3.9039e-05
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.2311e-05 - val_accuracy: 1.0000 - val_loss: 3.8070e-05
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 6.0100e-05 - val_accuracy: 1.0000 - val_loss: 3.7145e-05
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 5.2301e-05 - val_accuracy: 1.0000 - val_loss: 3.6260e-05
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.8045e-05 - val_accuracy: 1.0000 - val_loss: 3.5434e-05
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.0293e-05 - val_accuracy: 1.0000 - val_loss: 3.4646e-05
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.0738e-05 - val_accuracy: 1.0000 - val_loss: 3.3908e-05
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.8430e-05 - val_accuracy: 1.0000 - val_loss: 3.3223e-05
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 4.2018e-05 - val_accuracy: 1.0000 - val_loss: 3.2576e-05
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.4016e-05 - val_accuracy: 1.0000 - val_loss: 3.1976e-05
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.7675e-05 - val_accuracy: 1.0000 - val_loss: 3.1374e-05
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.5460e-05 - val_accuracy: 1.0000 - val_loss: 3.0806e-05
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 4.1416e-05 - val_accuracy: 1.0000 - val_loss: 3.0263e-05
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.1265e-05 - val_accuracy: 1.0000 - val_loss: 2.9740e-05
#
# Test Accuracy: 1.0000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# Model saved as 'query_classifier_model.keras'

# %%
# Test prediction
test_query = "what is your name "
print(f"\nPrediction for '{test_query}': {predict_query(test_query)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Prediction for 'what is your name ': language
